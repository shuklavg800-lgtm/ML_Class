# %%
# set functions
set1={"apple","banana","orange"}
set2={1,2,3,4,"apple"}
print(len(set1.intersection(set2)))
# Out:
# 1

# %%
#to return the no of classrooms required
subject={"java","cpp","python","cpp","c","php","Javascript","ruby","java"}
print(len(subject))
subject
# Out:
# 7
# {'Javascript', 'c', 'cpp', 'java', 'php', 'python', 'ruby'}

# %%
# to store 9 and 9.0 as separate elements in a set
# using set as the key value pair and pushing it in the set
a=9
set1={("number",9.0),("number",9)}
set1
# Out:
# {('number', 9.0)}

# %%
n=int(input("Enter a number"))
a=1
while a<=10:
    print(a*n)
    a=a+1
